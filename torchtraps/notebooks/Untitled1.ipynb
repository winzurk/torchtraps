# %%
from pycocotools.coco import COCO
import json
from coco_camera_traps_loader import load_image
import torch
import matplotlib.pyplot as plt
import numpy as np
from torchvision.datasets import CocoDetection
import torch.utils.data as data
from PIL import Image
import os

# %%
json_file = 'lila/SS_S1/SnapshotSerengetiBboxes_20190903.json'

# %%
with open(json_file) as f:
    dataset = json.load(f)

# %%
dataset['images']
# Out:
# [{'id': 'S1/D05/D05_R5/S1_D05_R5_PICT1288',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/D05/D05_R5/S1_D05_R5_PICT1288.JPG',
#   'datetime': '2010-10-08 12:45:34',
#   'seq_num_frames': 3,
#   'location': 'D05',
#   'height': 1536,
#   'seq_id': 'ASG0002uz2'},
#  {'id': 'S6/E03/E03_R2/S6_E03_R2_IMAG1342',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/E03/E03_R2/S6_E03_R2_IMAG1342.JPG',
#   'datetime': '2013-03-26 11:47:57',
#   'seq_num_frames': 3,
#   'location': 'E03',
#   'height': 1536,
#   'seq_id': 'ASG000yrit'},
#  {'id': 'S5/E02/E02_R1/S5_E02_R1_IMAG0672',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/E02/E02_R1/S5_E02_R1_IMAG0672.JPG',
#   'datetime': '2012-05-18 15:29:26',
#   'seq_num_frames': 3,
#   'location': 'E02',
#   'height': 1536,
#   'seq_id': 'ASG000ofxi'},
#  {'id': 'S6/C09/C09_R1/S6_C09_R1_IMAG0070',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/C09/C09_R1/S6_C09_R1_IMAG0070.JPG',
#   'datetime': '2012-12-14 09:59:30',
#   'seq_num_frames': 3,
#   'location': 'C09',
#   'height': 1536,
#   'seq_id': 'ASG000yaqx'},
#  {'id': 'S2/K03/K03_R2/S2_K03_R2_IMAG0116',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/K03/K03_R2/S2_K03_R2_IMAG0116.JPG',
#   'datetime': '2011-05-01 17:10:40',
#   'seq_num_frames': 3,
#   'location': 'K03',
#   'height': 1536,
#   'seq_id': 'ASG000789s'},
#  {'id': 'S1/K09/K09_R1/S1_K09_R1_PICT5773',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/K09/K09_R1/S1_K09_R1_PICT5773.JPG',
#   'datetime': '2010-10-13 13:55:08',
#   'seq_num_frames': 3,
#   'location': 'K09',
#   'height': 1536,
#   'seq_id': 'ASG0001i1q'},
#  {'id': 'S3/E04/E04_R11/S3_E04_R11_IMAG0262',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E04/E04_R11/S3_E04_R11_IMAG0262.JPG',
#   'datetime': '2011-09-03 12:50:26',
#   'seq_num_frames': 3,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG0007z95'},
#  {'id': 'S5/B06/B06_R1/S5_B06_R1_IMAG0325',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B06/B06_R1/S5_B06_R1_IMAG0325.JPG',
#   'datetime': '2012-06-02 06:33:25',
#   'seq_num_frames': 3,
#   'location': 'B06',
#   'height': 1536,
#   'seq_id': 'ASG000n1iq'},
#  {'id': 'S2/V13/V13_R1/S2_V13_R1_IMAG0032',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/V13/V13_R1/S2_V13_R1_IMAG0032.JPG',
#   'datetime': '2011-03-15 01:13:27',
#   'seq_num_frames': 1,
#   'location': 'V13',
#   'height': 1536,
#   'seq_id': 'ASG00076jv'},
#  {'id': 'S3/I13/I13_R11/S3_I13_R11_IMAG0554',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/I13/I13_R11/S3_I13_R11_IMAG0554.JPG',
#   'datetime': '2011-10-21 14:47:50',
#   'seq_num_frames': 3,
#   'location': 'I13',
#   'height': 1536,
#   'seq_id': 'ASG0008atp'},
#  {'id': 'S4/K07/K07_R1/S4_K07_R1_IMAG2168',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/K07/K07_R1/S4_K07_R1_IMAG2168.JPG',
#   'datetime': '2012-03-17 16:08:37',
#   'seq_num_frames': 3,
#   'location': 'K07',
#   'height': 1536,
#   'seq_id': 'ASG000bf9f'},
#  {'id': 'S4/F12/F12_R1/S4_F12_R1_IMAG0646',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/F12/F12_R1/S4_F12_R1_IMAG0646.JPG',
#   'datetime': '2012-01-30 15:48:32',
#   'seq_num_frames': 3,
#   'location': 'F12',
#   'height': 1536,
#   'seq_id': 'ASG000bkhk'},
#  {'id': 'S5/P10/P10_R1/S5_P10_R1_IMAG1392',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/P10/P10_R1/S5_P10_R1_IMAG1392.JPG',
#   'datetime': '2012-07-13 18:32:45',
#   'seq_num_frames': 3,
#   'location': 'P10',
#   'height': 1536,
#   'seq_id': 'ASG000sn3z'},
#  {'id': 'S1/G01/G01_R1/S1_G01_R1_PICT0063',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/G01/G01_R1/S1_G01_R1_PICT0063.JPG',
#   'datetime': '2010-09-19 08:10:04',
#   'seq_num_frames': 3,
#   'location': 'G01',
#   'height': 1536,
#   'seq_id': 'ASG0000286'},
#  {'id': 'S4/T13/T13_R2/S4_T13_R2_IMAG1875',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/T13/T13_R2/S4_T13_R2_IMAG1875.JPG',
#   'datetime': '2012-03-28 17:53:33',
#   'seq_num_frames': 3,
#   'location': 'T13',
#   'height': 1536,
#   'seq_id': 'ASG000c3gl'},
#  {'id': 'S5/H02/H02_R3/S5_H02_R3_IMAG0080',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/H02/H02_R3/S5_H02_R3_IMAG0080.JPG',
#   'datetime': '2012-09-29 12:04:23',
#   'seq_num_frames': 3,
#   'location': 'H02',
#   'height': 1536,
#   'seq_id': 'ASG000pmez'},
#  {'id': 'S4/K07/K07_R1/S4_K07_R1_IMAG0282',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/K07/K07_R1/S4_K07_R1_IMAG0282.JPG',
#   'datetime': '2012-02-20 10:33:12',
#   'seq_num_frames': 3,
#   'location': 'K07',
#   'height': 1536,
#   'seq_id': 'ASG000bfmh'},
#  {'id': 'S6/B08/B08_R1/S6_B08_R1_IMAG0722',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/B08/B08_R1/S6_B08_R1_IMAG0722.JPG',
#   'seq_num_frames': 3,
#   'location': 'B08',
#   'height': 1536,
#   'seq_id': 'ASG000y3ja'},
#  {'id': 'S3/E05/E05_R11/S3_E05_R11_IMAG0286',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E05/E05_R11/S3_E05_R11_IMAG0286.JPG',
#   'datetime': '2011-09-22 19:16:12',
#   'seq_num_frames': 1,
#   'location': 'E05',
#   'height': 1536,
#   'seq_id': 'ASG0007zss'},
#  {'id': 'S2/D12/D12_R3/S2_D12_R3_PICT0332',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/D12/D12_R3/S2_D12_R3_PICT0332.JPG',
#   'datetime': '2011-07-01 11:32:30',
#   'seq_num_frames': 3,
#   'location': 'D12',
#   'height': 1536,
#   'seq_id': 'ASG00049rb'},
#  {'id': 'S5/D10/D10_R1/S5_D10_R1_IMAG1357',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/D10/D10_R1/S5_D10_R1_IMAG1357.JPG',
#   'datetime': '2012-06-01 12:25:31',
#   'seq_num_frames': 3,
#   'location': 'D10',
#   'height': 1536,
#   'seq_id': 'ASG000o716'},
#  {'id': 'S5/K10/K10_R2/S5_K10_R2_IMAG1415',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/K10/K10_R2/S5_K10_R2_IMAG1415.JPG',
#   'datetime': '2012-09-30 14:49:27',
#   'seq_num_frames': 3,
#   'location': 'K10',
#   'height': 1536,
#   'seq_id': 'ASG000qvs7'},
#  {'id': 'S1/H08/H08_R1/S1_H08_R1_PICT0554',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H08/H08_R1/S1_H08_R1_PICT0554.JPG',
#   'datetime': '2010-10-19 07:41:30',
#   'seq_num_frames': 3,
#   'location': 'H08',
#   'height': 1536,
#   'seq_id': 'ASG00013d9'},
#  {'id': 'S3/M08/M08_R11/S3_M08_R11_IMAG0513',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/M08/M08_R11/S3_M08_R11_IMAG0513.JPG',
#   'datetime': '2011-10-12 08:49:50',
#   'seq_num_frames': 3,
#   'location': 'M08',
#   'height': 1536,
#   'seq_id': 'ASG0008kru'},
#  {'id': 'S6/J04/J04_R1/S6_J04_R1_IMAG0139',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/J04/J04_R1/S6_J04_R1_IMAG0139.JPG',
#   'datetime': '2012-12-19 08:19:32',
#   'seq_num_frames': 3,
#   'location': 'J04',
#   'height': 1536,
#   'seq_id': 'ASG000ztjz'},
#  {'id': 'S5/O06/O06_R3/S5_O06_R3_IMAG0556',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/O06/O06_R3/S5_O06_R3_IMAG0556.JPG',
#   'datetime': '2012-12-14 16:05:59',
#   'seq_num_frames': 3,
#   'location': 'O06',
#   'height': 1536,
#   'seq_id': 'ASG000s8il'},
#  {'id': 'S5/J05/J05_R3/S5_J05_R3_IMAG0356',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/J05/J05_R3/S5_J05_R3_IMAG0356.JPG',
#   'datetime': '2012-11-23 08:43:50',
#   'seq_num_frames': 3,
#   'location': 'J05',
#   'height': 1536,
#   'seq_id': 'ASG000qlc7'},
#  {'id': 'S1/G07/G07_R2/S1_G07_R2_PICT0935',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/G07/G07_R2/S1_G07_R2_PICT0935.JPG',
#   'datetime': '2010-10-11 08:01:22',
#   'seq_num_frames': 3,
#   'location': 'G07',
#   'height': 1536,
#   'seq_id': 'ASG00005td'},
#  {'id': 'S6/T11/T11_R2/S6_T11_R2_IMAG0102',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/T11/T11_R2/S6_T11_R2_IMAG0102.JPG',
#   'datetime': '2013-03-03 15:45:23',
#   'seq_num_frames': 3,
#   'location': 'T11',
#   'height': 1536,
#   'seq_id': 'ASG0011lk0'},
#  {'id': 'S4/U09/U09_R2/S4_U09_R2_IMAG1288',
#   'frame_num': 1,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/U09/U09_R2/S4_U09_R2_IMAG1288.JPG',
#   'datetime': '2012-04-14 13:28:27',
#   'seq_num_frames': 3,
#   'location': 'U09',
#   'height': 1536,
#   'seq_id': 'ASG000cl8y'},
#  {'id': 'S6/I12/I12_R2/S6_I12_R2_IMAG0206',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/I12/I12_R2/S6_I12_R2_IMAG0206.JPG',
#   'datetime': '2013-02-11 11:08:02',
#   'seq_num_frames': 3,
#   'location': 'I12',
#   'height': 1536,
#   'seq_id': 'ASG000zqz1'},
#  {'id': 'S5/U12/U12_R1/S5_U12_R1_IMAG0620',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/U12/U12_R1/S5_U12_R1_IMAG0620.JPG',
#   'datetime': '2012-05-16 06:38:23',
#   'seq_num_frames': 3,
#   'location': 'U12',
#   'height': 1536,
#   'seq_id': 'ASG000tud8'},
#  {'id': 'S1/I13/I13_R1/S1_I13_R1_PICT0789',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/I13/I13_R1/S1_I13_R1_PICT0789.JPG',
#   'datetime': '2010-10-03 12:48:24',
#   'seq_num_frames': 3,
#   'location': 'I13',
#   'height': 1536,
#   'seq_id': 'ASG0001cum'},
#  {'id': 'S1/E06/E06_R4/S1_E06_R4_PICT0591',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/E06/E06_R4/S1_E06_R4_PICT0591.JPG',
#   'datetime': '2010-08-24 02:47:56',
#   'seq_num_frames': 3,
#   'location': 'E06',
#   'height': 1536,
#   'seq_id': 'ASG0002hpj'},
#  {'id': 'S3/M08/M08_R11/S3_M08_R11_IMAG0948',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/M08/M08_R11/S3_M08_R11_IMAG0948.JPG',
#   'datetime': '2011-11-02 11:12:46',
#   'seq_num_frames': 3,
#   'location': 'M08',
#   'height': 1536,
#   'seq_id': 'ASG0008kp1'},
#  {'id': 'S5/G02/G02_R2/S5_G02_R2_IMAG0954',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/G02/G02_R2/S5_G02_R2_IMAG0954.JPG',
#   'datetime': '2012-09-19 21:16:06',
#   'seq_num_frames': 1,
#   'location': 'G02',
#   'height': 1536,
#   'seq_id': 'ASG000p8jn'},
#  {'id': 'S6/O07/O07_R1/S6_O07_R1_IMAG0183',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/O07/O07_R1/S6_O07_R1_IMAG0183.JPG',
#   'datetime': '2013-01-13 17:45:35',
#   'seq_num_frames': 3,
#   'location': 'O07',
#   'height': 1536,
#   'seq_id': 'ASG0010ss1'},
#  {'id': 'S4/K07/K07_R1/S4_K07_R1_IMAG2128',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/K07/K07_R1/S4_K07_R1_IMAG2128.JPG',
#   'datetime': '2012-03-12 14:10:13',
#   'seq_num_frames': 3,
#   'location': 'K07',
#   'height': 1536,
#   'seq_id': 'ASG000bfdm'},
#  {'id': 'S2/F12/F12_R1/S2_F12_R1_IMAG0236',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F12/F12_R1/S2_F12_R1_IMAG0236.JPG',
#   'datetime': '2011-03-10 15:20:23',
#   'seq_num_frames': 3,
#   'location': 'F12',
#   'height': 1536,
#   'seq_id': 'ASG0004yhi'},
#  {'id': 'S2/O08/O08_R1/S2_O08_R1_PICT0115',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/O08/O08_R1/S2_O08_R1_PICT0115.JPG',
#   'datetime': '2011-03-03 13:37:23',
#   'seq_num_frames': 3,
#   'location': 'O08',
#   'height': 1536,
#   'seq_id': 'ASG0006a74'},
#  {'id': 'S4/J03/J03_R1/S4_J03_R1_IMAG2238',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/J03/J03_R1/S4_J03_R1_IMAG2238.JPG',
#   'datetime': '2012-02-21 17:55:05',
#   'seq_num_frames': 3,
#   'location': 'J03',
#   'height': 1536,
#   'seq_id': 'ASG000cm8g'},
#  {'id': 'S3/P04/P04_R11/S3_P04_R11_IMAG0269',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/P04/P04_R11/S3_P04_R11_IMAG0269.JPG',
#   'datetime': '2011-11-01 13:57:40',
#   'seq_num_frames': 3,
#   'location': 'P04',
#   'height': 1536,
#   'seq_id': 'ASG0008osz'},
#  {'id': 'S3/E04/E04_R11/S3_E04_R11_IMAG0544',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E04/E04_R11/S3_E04_R11_IMAG0544.JPG',
#   'datetime': '2011-09-13 20:00:46',
#   'seq_num_frames': 1,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG0007z6f'},
#  {'id': 'S1/F12/F12_R1/S1_F12_R1_PICT0906',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F12/F12_R1/S1_F12_R1_PICT0906.JPG',
#   'datetime': '2010-10-02 05:32:52',
#   'seq_num_frames': 3,
#   'location': 'F12',
#   'height': 1536,
#   'seq_id': 'ASG0000ubr'},
#  {'id': 'S6/S13/S13_R2/S6_S13_R2_IMAG0127',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/S13/S13_R2/S6_S13_R2_IMAG0127.JPG',
#   'datetime': '2013-03-12 16:09:22',
#   'seq_num_frames': 3,
#   'location': 'S13',
#   'height': 1536,
#   'seq_id': 'ASG0011k1m'},
#  {'id': 'S5/B06/B06_R1/S5_B06_R1_IMAG2123',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B06/B06_R1/S5_B06_R1_IMAG2123.JPG',
#   'datetime': '2012-07-21 06:30:15',
#   'seq_num_frames': 3,
#   'location': 'B06',
#   'height': 1536,
#   'seq_id': 'ASG000n262'},
#  {'id': 'S1/P10/P10_R1/S1_P10_R1_PICT0112',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/P10/P10_R1/S1_P10_R1_PICT0112.JPG',
#   'datetime': '2010-09-14 00:36:40',
#   'seq_num_frames': 3,
#   'location': 'P10',
#   'height': 1536,
#   'seq_id': 'ASG0000ey1'},
#  {'id': 'S1/F06/F06_R3/S1_F06_R3_PICT0082',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F06/F06_R3/S1_F06_R3_PICT0082.JPG',
#   'datetime': '2010-08-22 22:24:42',
#   'seq_num_frames': 3,
#   'location': 'F06',
#   'height': 1536,
#   'seq_id': 'ASG0002kio'},
#  {'id': 'S2/C08/C08_R1/S2_C08_R1_IMAG0498',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/C08/C08_R1/S2_C08_R1_IMAG0498.JPG',
#   'datetime': '2011-04-13 12:58:28',
#   'seq_num_frames': 3,
#   'location': 'C08',
#   'height': 1536,
#   'seq_id': 'ASG0003rb7'},
#  {'id': 'S6/B12/B12_R1/S6_B12_R1_IMAG0741',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/B12/B12_R1/S6_B12_R1_IMAG0741.JPG',
#   'datetime': '2013-02-01 17:49:34',
#   'seq_num_frames': 3,
#   'location': 'B12',
#   'height': 1536,
#   'seq_id': 'ASG000y4xi'},
#  {'id': 'S3/L05/L05_R11/S3_L05_R11_IMAG0073',
#   'frame_num': 1,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/L05/L05_R11/S3_L05_R11_IMAG0073.JPG',
#   'datetime': '2011-09-22 11:08:40',
#   'seq_num_frames': 3,
#   'location': 'L05',
#   'height': 1536,
#   'seq_id': 'ASG0008hlz'},
#  {'id': 'S6/L04/L04_R1/S6_L04_R1_IMAG0494',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/L04/L04_R1/S6_L04_R1_IMAG0494.JPG',
#   'datetime': '2013-01-31 12:09:35',
#   'seq_num_frames': 3,
#   'location': 'L04',
#   'height': 1536,
#   'seq_id': 'ASG00106m0'},
#  {'id': 'S6/M02/M02_R2/S6_M02_R2_IMAG0048',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/M02/M02_R2/S6_M02_R2_IMAG0048.JPG',
#   'datetime': '2013-02-15 06:50:43',
#   'seq_num_frames': 3,
#   'location': 'M02',
#   'height': 1536,
#   'seq_id': 'ASG0010cx4'},
#  {'id': 'S5/P05/P05_R1/S5_P05_R1_IMAG0175',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/P05/P05_R1/S5_P05_R1_IMAG0175.JPG',
#   'datetime': '2011-11-10 08:56:19',
#   'seq_num_frames': 3,
#   'location': 'P05',
#   'height': 1536,
#   'seq_id': 'ASG000skko'},
#  {'id': 'S4/F03/F03_R1/S4_F03_R1_IMAG0010',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/F03/F03_R1/S4_F03_R1_IMAG0010.JPG',
#   'datetime': '2012-01-04 01:16:04',
#   'seq_num_frames': 1,
#   'location': 'F03',
#   'height': 1536,
#   'seq_id': 'ASG000elst'},
#  {'id': 'S4/S12/S12_R2/S4_S12_R2_IMAG0233',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/S12/S12_R2/S4_S12_R2_IMAG0233.JPG',
#   'datetime': '2012-02-10 12:54:41',
#   'seq_num_frames': 3,
#   'location': 'S12',
#   'height': 1536,
#   'seq_id': 'ASG000bzco'},
#  {'id': 'S2/G09/G09_R3/S2_G09_R3_PICT0604',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G09/G09_R3/S2_G09_R3_PICT0604.JPG',
#   'datetime': '2011-05-30 19:49:45',
#   'seq_num_frames': 3,
#   'location': 'G09',
#   'height': 1536,
#   'seq_id': 'ASG0005awi'},
#  {'id': 'S4/L05/L05_R2/S4_L05_R2_IMAG1229',
#   'frame_num': 1,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/L05/L05_R2/S4_L05_R2_IMAG1229.JPG',
#   'datetime': '2012-04-21 12:12:26',
#   'seq_num_frames': 3,
#   'location': 'L05',
#   'height': 1536,
#   'seq_id': 'ASG000csxp'},
#  {'id': 'S6/S13/S13_R2/S6_S13_R2_IMAG0079',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/S13/S13_R2/S6_S13_R2_IMAG0079.JPG',
#   'datetime': '2013-03-08 16:20:59',
#   'seq_num_frames': 3,
#   'location': 'S13',
#   'height': 1536,
#   'seq_id': 'ASG0011k14'},
#  {'id': 'S5/D02/D02_R3/S5_D02_R3_IMAG0836',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/D02/D02_R3/S5_D02_R3_IMAG0836.JPG',
#   'datetime': '2012-10-26 12:24:29',
#   'seq_num_frames': 3,
#   'location': 'D02',
#   'height': 1536,
#   'seq_id': 'ASG000nrtx'},
#  {'id': 'S1/I13/I13_R2/S1_I13_R2_PICT0015',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/I13/I13_R2/S1_I13_R2_PICT0015.JPG',
#   'datetime': '2010-10-26 06:51:38',
#   'seq_num_frames': 3,
#   'location': 'I13',
#   'height': 1536,
#   'seq_id': 'ASG0001d4b'},
#  {'id': 'S6/D06/D06_R2/S6_D06_R2_IMAG0078',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/D06/D06_R2/S6_D06_R2_IMAG0078.JPG',
#   'datetime': '2013-02-21 22:04:47',
#   'seq_num_frames': 1,
#   'location': 'D06',
#   'height': 1536,
#   'seq_id': 'ASG000yje1'},
#  {'id': 'S5/M03/M03_R3/S5_M03_R3_IMAG2262',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/M03/M03_R3/S5_M03_R3_IMAG2262.JPG',
#   'datetime': '2012-11-26 11:41:53',
#   'seq_num_frames': 3,
#   'location': 'M03',
#   'height': 1536,
#   'seq_id': 'ASG000rb1r'},
#  {'id': 'S1/R09/R09_R1/S1_R09_R1_PICT0043',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/R09/R09_R1/S1_R09_R1_PICT0043.JPG',
#   'datetime': '2010-09-13 14:43:26',
#   'seq_num_frames': 3,
#   'location': 'R09',
#   'height': 1536,
#   'seq_id': 'ASG0000frn'},
#  {'id': 'S4/E08/E08_R1/S4_E08_R1_IMAG0002',
#   'frame_num': 1,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/E08/E08_R1/S4_E08_R1_IMAG0002.JPG',
#   'datetime': '2011-12-29 16:57:42',
#   'seq_num_frames': 3,
#   'location': 'E08',
#   'height': 1536,
#   'seq_id': 'ASG000c0mh'},
#  {'id': 'S2/M04/M04_R2/S2_M04_R2_IMAG0613',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/M04/M04_R2/S2_M04_R2_IMAG0613.JPG',
#   'datetime': '2011-06-11 19:35:06',
#   'seq_num_frames': 1,
#   'location': 'M04',
#   'height': 1536,
#   'seq_id': 'ASG0006vz7'},
#  {'id': 'S6/L04/L04_R1/S6_L04_R1_IMAG0585',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/L04/L04_R1/S6_L04_R1_IMAG0585.JPG',
#   'datetime': '2013-01-31 12:50:34',
#   'seq_num_frames': 3,
#   'location': 'L04',
#   'height': 1536,
#   'seq_id': 'ASG00106mw'},
#  {'id': 'S5/C12/C12_R3/S5_C12_R3_IMAG0126',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/C12/C12_R3/S5_C12_R3_IMAG0126.JPG',
#   'datetime': '2012-10-18 17:46:07',
#   'seq_num_frames': 3,
#   'location': 'C12',
#   'height': 1536,
#   'seq_id': 'ASG000nnrm'},
#  {'id': 'S5/P04/P04_R3/S5_P04_R3_IMAG3341',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/P04/P04_R3/S5_P04_R3_IMAG3341.JPG',
#   'datetime': '2012-11-26 09:44:51',
#   'seq_num_frames': 3,
#   'location': 'P04',
#   'height': 1536,
#   'seq_id': 'ASG000sk8g'},
#  {'id': 'S2/R08/R08_R2/S2_R08_R2_IMAG0595',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/R08/R08_R2/S2_R08_R2_IMAG0595.JPG',
#   'datetime': '2011-06-25 17:34:11',
#   'seq_num_frames': 3,
#   'location': 'R08',
#   'height': 1536,
#   'seq_id': 'ASG0006nlb'},
#  {'id': 'S1/K09/K09_R1/S1_K09_R1_PICT5665',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/K09/K09_R1/S1_K09_R1_PICT5665.JPG',
#   'datetime': '2010-10-11 18:37:20',
#   'seq_num_frames': 3,
#   'location': 'K09',
#   'height': 1536,
#   'seq_id': 'ASG0001i0q'},
#  {'id': 'S5/H07/H07_R2/S5_H07_R2_IMAG1035',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/H07/H07_R2/S5_H07_R2_IMAG1035.JPG',
#   'datetime': '2012-09-17 15:28:41',
#   'seq_num_frames': 3,
#   'location': 'H07',
#   'height': 1536,
#   'seq_id': 'ASG000pula'},
#  {'id': 'S2/J08/J08_R1/S2_J08_R1_PICT0354',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/J08/J08_R1/S2_J08_R1_PICT0354.JPG',
#   'datetime': '2011-02-28 09:57:09',
#   'seq_num_frames': 3,
#   'location': 'J08',
#   'height': 1536,
#   'seq_id': 'ASG000667y'},
#  {'id': 'S5/I12/I12_R1/S5_I12_R1_IMAG0409',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/I12/I12_R1/S5_I12_R1_IMAG0409.JPG',
#   'datetime': '2012-06-08 12:19:50',
#   'seq_num_frames': 3,
#   'location': 'I12',
#   'height': 1536,
#   'seq_id': 'ASG000qbu1'},
#  {'id': 'S6/R09/R09_R2/S6_R09_R2_IMAG0056',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/R09/R09_R2/S6_R09_R2_IMAG0056.JPG',
#   'datetime': '2013-04-05 13:42:44',
#   'seq_num_frames': 3,
#   'location': 'R09',
#   'height': 1536,
#   'seq_id': 'ASG0011bky'},
#  {'id': 'S2/N10/N10_R1/S2_N10_R1_PICT0106',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/N10/N10_R1/S2_N10_R1_PICT0106.JPG',
#   'datetime': '2011-03-05 22:16:34',
#   'seq_num_frames': 3,
#   'location': 'N10',
#   'height': 1536,
#   'seq_id': 'ASG000708z'},
#  {'id': 'S1/O10/O10_R1/S1_O10_R1_PICT1375',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/O10/O10_R1/S1_O10_R1_PICT1375.JPG',
#   'datetime': '2010-09-08 20:24:20',
#   'seq_num_frames': 3,
#   'location': 'O10',
#   'height': 1536,
#   'seq_id': 'ASG0000cub'},
#  {'id': 'S6/D10/D10_R2/S6_D10_R2_IMAG0216',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/D10/D10_R2/S6_D10_R2_IMAG0216.JPG',
#   'datetime': '2013-02-01 00:17:48',
#   'seq_num_frames': 1,
#   'location': 'D10',
#   'height': 1536,
#   'seq_id': 'ASG000ylhc'},
#  {'id': 'S2/O06/O06_R2/S2_O06_R2_IMAG1058',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/O06/O06_R2/S2_O06_R2_IMAG1058.JPG',
#   'datetime': '2011-07-22 04:16:13',
#   'seq_num_frames': 1,
#   'location': 'O06',
#   'height': 1536,
#   'seq_id': 'ASG00069p6'},
#  {'id': 'S1/J10/J10_R2/S1_J10_R2_PICT0016',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/J10/J10_R2/S1_J10_R2_PICT0016.JPG',
#   'datetime': '2010-10-27 21:53:48',
#   'seq_num_frames': 3,
#   'location': 'J10',
#   'height': 1536,
#   'seq_id': 'ASG0001fev'},
#  {'id': 'S3/L11/L11_R12/S3_L11_R12_IMAG0829',
#   'frame_num': 1,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/L11/L11_R12/S3_L11_R12_IMAG0829.JPG',
#   'datetime': '2012-01-13 08:52:30',
#   'seq_num_frames': 3,
#   'location': 'L11',
#   'height': 1536,
#   'seq_id': 'ASG000akub'},
#  {'id': 'S1/O10/O10_R1/S1_O10_R1_PICT0236',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/O10/O10_R1/S1_O10_R1_PICT0236.JPG',
#   'datetime': '2010-09-05 10:55:58',
#   'seq_num_frames': 3,
#   'location': 'O10',
#   'height': 1536,
#   'seq_id': 'ASG0000cjs'},
#  {'id': 'S5/C12/C12_R3/S5_C12_R3_IMAG1882',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/C12/C12_R3/S5_C12_R3_IMAG1882.JPG',
#   'datetime': '2012-12-02 12:50:43',
#   'seq_num_frames': 3,
#   'location': 'C12',
#   'height': 1536,
#   'seq_id': 'ASG000noaf'},
#  {'id': 'S3/S10/S10_R11/S3_S10_R11_IMAG0027',
#   'frame_num': 1,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/S10/S10_R11/S3_S10_R11_IMAG0027.JPG',
#   'datetime': '2011-10-05 11:37:59',
#   'seq_num_frames': 3,
#   'location': 'S10',
#   'height': 1536,
#   'seq_id': 'ASG0008tjl'},
#  {'id': 'S4/R10/R10_R2/S4_R10_R2_IMAG3626',
#   'frame_num': 1,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/R10/R10_R2/S4_R10_R2_IMAG3626.JPG',
#   'datetime': '2012-03-16 10:52:43',
#   'seq_num_frames': 3,
#   'location': 'R10',
#   'height': 1536,
#   'seq_id': 'ASG000fh76'},
#  {'id': 'S1/J03/J03_R1/S1_J03_R1_PICT2592',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/J03/J03_R1/S1_J03_R1_PICT2592.JPG',
#   'datetime': '2010-10-23 15:58:16',
#   'seq_num_frames': 3,
#   'location': 'J03',
#   'height': 1536,
#   'seq_id': 'ASG0002dox'},
#  {'id': 'S1/K08/K08_R1/S1_K08_R1_PICT1400',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/K08/K08_R1/S1_K08_R1_PICT1400.JPG',
#   'datetime': '2010-10-27 03:35:30',
#   'seq_num_frames': 3,
#   'location': 'K08',
#   'height': 1536,
#   'seq_id': 'ASG0001gjs'},
#  {'id': 'S1/K09/K09_R1/S1_K09_R1_PICT5372',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/K09/K09_R1/S1_K09_R1_PICT5372.JPG',
#   'datetime': '2010-10-07 11:14:58',
#   'seq_num_frames': 3,
#   'location': 'K09',
#   'height': 1536,
#   'seq_id': 'ASG0001hy0'},
#  {'id': 'S1/G09/G09_R1/S1_G09_R1_PICT0110',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/G09/G09_R1/S1_G09_R1_PICT0110.JPG',
#   'datetime': '2010-09-05 16:07:16',
#   'seq_num_frames': 3,
#   'location': 'G09',
#   'height': 1536,
#   'seq_id': 'ASG0000yvh'},
#  {'id': 'S6/V10/V10_R1/S6_V10_R1_IMAG0409',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/V10/V10_R1/S6_V10_R1_IMAG0409.JPG',
#   'datetime': '2013-01-28 08:39:26',
#   'seq_num_frames': 3,
#   'location': 'V10',
#   'height': 1536,
#   'seq_id': 'ASG0011w14'},
#  {'id': 'S5/B09/B09_R3/S5_B09_R3_IMAG0352',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B09/B09_R3/S5_B09_R3_IMAG0352.JPG',
#   'datetime': '2012-11-01 07:24:17',
#   'seq_num_frames': 3,
#   'location': 'B09',
#   'height': 1536,
#   'seq_id': 'ASG000n88b'},
#  {'id': 'S2/H07/H07_R3/S2_H07_R3_PICT5728',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/H07/H07_R3/S2_H07_R3_PICT5728.JPG',
#   'datetime': '2011-06-19 13:36:49',
#   'seq_num_frames': 3,
#   'location': 'H07',
#   'height': 1536,
#   'seq_id': 'ASG0003vzz'},
#  {'id': 'S5/O09/O09_R2/S5_O09_R2_IMAG1280',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/O09/O09_R2/S5_O09_R2_IMAG1280.JPG',
#   'datetime': '2012-09-23 04:16:54',
#   'seq_num_frames': 1,
#   'location': 'O09',
#   'height': 1536,
#   'seq_id': 'ASG000s9kh'},
#  {'id': 'S1/F08/F08_R3/S1_F08_R3_PICT3034',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F08/F08_R3/S1_F08_R3_PICT3034.JPG',
#   'datetime': '2010-09-26 08:55:20',
#   'seq_num_frames': 3,
#   'location': 'F08',
#   'height': 1536,
#   'seq_id': 'ASG0000s8x'},
#  {'id': 'S5/G06/G06_R1/S5_G06_R1_IMAG0082',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/G06/G06_R1/S5_G06_R1_IMAG0082.JPG',
#   'datetime': '2012-06-10 11:06:23',
#   'seq_num_frames': 3,
#   'location': 'G06',
#   'height': 1536,
#   'seq_id': 'ASG000pc60'},
#  {'id': 'S3/M08/M08_R11/S3_M08_R11_IMAG0949',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/M08/M08_R11/S3_M08_R11_IMAG0949.JPG',
#   'datetime': '2011-11-02 11:15:26',
#   'seq_num_frames': 3,
#   'location': 'M08',
#   'height': 1536,
#   'seq_id': 'ASG0008kvn'},
#  {'id': 'S5/B13/B13_R1/S5_B13_R1_IMAG0801',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B13/B13_R1/S5_B13_R1_IMAG0801.JPG',
#   'datetime': '2012-07-01 13:15:52',
#   'seq_num_frames': 3,
#   'location': 'B13',
#   'height': 1536,
#   'seq_id': 'ASG000muqr'},
#  {'id': 'S5/J03/J03_R2/S5_J03_R2_IMAG0364',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/J03/J03_R2/S5_J03_R2_IMAG0364.JPG',
#   'datetime': '2012-08-09 17:20:45',
#   'seq_num_frames': 3,
#   'location': 'J03',
#   'height': 1536,
#   'seq_id': 'ASG000qivb'},
#  {'id': 'S2/G11/G11_R2/S2_G11_R2_IMAG0612',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G11/G11_R2/S2_G11_R2_IMAG0612.JPG',
#   'datetime': '2011-03-25 18:24:44',
#   'seq_num_frames': 3,
#   'location': 'G11',
#   'height': 1536,
#   'seq_id': 'ASG0005cvb'},
#  {'id': 'S4/Q05/Q05_R1/S4_Q05_R1_IMAG0234',
#   'frame_num': 1,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/Q05/Q05_R1/S4_Q05_R1_IMAG0234.JPG',
#   'datetime': '2012-03-12 11:08:27',
#   'seq_num_frames': 3,
#   'location': 'Q05',
#   'height': 1536,
#   'seq_id': 'ASG000blm1'},
#  {'id': 'S5/T09/T09_R3/S5_T09_R3_IMAG0045',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/T09/T09_R3/S5_T09_R3_IMAG0045.JPG',
#   'datetime': '2012-09-28 11:32:29',
#   'seq_num_frames': 3,
#   'location': 'T09',
#   'height': 1536,
#   'seq_id': 'ASG000tf16'},
#  {'id': 'S5/E09/E09_R1/S5_E09_R1_IMAG0554',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/E09/E09_R1/S5_E09_R1_IMAG0554.JPG',
#   'datetime': '2012-07-15 07:44:28',
#   'seq_num_frames': 3,
#   'location': 'E09',
#   'height': 1536,
#   'seq_id': 'ASG000omxv'},
#  {'id': 'S4/B05/B05_R2/S4_B05_R2_IMAG0495',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/B05/B05_R2/S4_B05_R2_IMAG0495.JPG',
#   'datetime': '2012-04-04 02:55:29',
#   'seq_num_frames': 1,
#   'location': 'B05',
#   'height': 1536,
#   'seq_id': 'ASG000e8do'},
#  {'id': 'S5/D13/D13_R3/S5_D13_R3_IMAG4729',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/D13/D13_R3/S5_D13_R3_IMAG4729.JPG',
#   'datetime': '2012-11-30 11:00:03',
#   'seq_num_frames': 3,
#   'location': 'D13',
#   'height': 1536,
#   'seq_id': 'ASG000oe8i'},
#  {'id': 'S2/F12/F12_R1/S2_F12_R1_IMAG0053',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F12/F12_R1/S2_F12_R1_IMAG0053.JPG',
#   'datetime': '2011-03-05 06:08:48',
#   'seq_num_frames': 1,
#   'location': 'F12',
#   'height': 1536,
#   'seq_id': 'ASG0004yi4'},
#  {'id': 'S3/G01/G01_R11/S3_G01_R11_IMAG0187',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/G01/G01_R11/S3_G01_R11_IMAG0187.JPG',
#   'datetime': '2011-11-06 15:19:03',
#   'seq_num_frames': 3,
#   'location': 'G01',
#   'height': 1536,
#   'seq_id': 'ASG0009dhr'},
#  {'id': 'S1/H06/H06_R4/S1_H06_R4_PICT1299',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H06/H06_R4/S1_H06_R4_PICT1299.JPG',
#   'datetime': '2010-10-22 22:13:34',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG000131z'},
#  {'id': 'S2/D02/D02_R4/S2_D02_R4_IMAG1556',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/D02/D02_R4/S2_D02_R4_IMAG1556.JPG',
#   'datetime': '2011-07-14 18:37:29',
#   'seq_num_frames': 3,
#   'location': 'D02',
#   'height': 1536,
#   'seq_id': 'ASG0003yha'},
#  {'id': 'S2/E09/E09_R3/S2_E09_R3_IMAG0128',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/E09/E09_R3/S2_E09_R3_IMAG0128.JPG',
#   'datetime': '2011-05-28 22:37:52',
#   'seq_num_frames': 1,
#   'location': 'E09',
#   'height': 1536,
#   'seq_id': 'ASG0004jah'},
#  {'id': 'S2/U13/U13_R3/S2_U13_R3_PICT0532',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/U13/U13_R3/S2_U13_R3_PICT0532.JPG',
#   'datetime': '2011-06-20 19:23:36',
#   'seq_num_frames': 3,
#   'location': 'U13',
#   'height': 1536,
#   'seq_id': 'ASG000746j'},
#  {'id': 'S2/T12/T12_R2/S2_T12_R2_PICT0831',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/T12/T12_R2/S2_T12_R2_PICT0831.JPG',
#   'datetime': '2011-04-13 07:02:52',
#   'seq_num_frames': 3,
#   'location': 'T12',
#   'height': 1536,
#   'seq_id': 'ASG00071re'},
#  {'id': 'S3/D06/D06_R11/S3_D06_R11_IMAG0017',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/D06/D06_R11/S3_D06_R11_IMAG0017.JPG',
#   'datetime': '2011-11-01 07:00:39',
#   'seq_num_frames': 3,
#   'location': 'D06',
#   'height': 1536,
#   'seq_id': 'ASG0008y9n'},
#  {'id': 'S3/S09/S09_R12/S3_S09_R12_IMAG1827',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/S09/S09_R12/S3_S09_R12_IMAG1827.JPG',
#   'datetime': '2012-01-12 14:14:50',
#   'seq_num_frames': 3,
#   'location': 'S09',
#   'height': 1536,
#   'seq_id': 'ASG000b0pp'},
#  {'id': 'S1/H06/H06_R4/S1_H06_R4_PICT1415',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H06/H06_R4/S1_H06_R4_PICT1415.JPG',
#   'datetime': '2010-11-01 09:43:06',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG0001332'},
#  {'id': 'S5/T10/T10_R4/S5_T10_R4_IMAG1115',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/T10/T10_R4/S5_T10_R4_IMAG1115.JPG',
#   'datetime': '2012-11-21 12:53:33',
#   'seq_num_frames': 3,
#   'location': 'T10',
#   'height': 1536,
#   'seq_id': 'ASG000tgb4'},
#  {'id': 'S5/G07/G07_R2/S5_G07_R2_IMAG0457',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/G07/G07_R2/S5_G07_R2_IMAG0457.JPG',
#   'datetime': '2012-09-13 11:50:02',
#   'seq_num_frames': 3,
#   'location': 'G07',
#   'height': 1536,
#   'seq_id': 'ASG000peug'},
#  {'id': 'S5/E03/E03_R2/S5_E03_R2_IMAG0108',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/E03/E03_R2/S5_E03_R2_IMAG0108.JPG',
#   'datetime': '2012-07-25 06:13:07',
#   'seq_num_frames': 1,
#   'location': 'E03',
#   'height': 1536,
#   'seq_id': 'ASG000ohaq'},
#  {'id': 'S5/I02/I02_R2/S5_I02_R2_IMAG0607',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/I02/I02_R2/S5_I02_R2_IMAG0607.JPG',
#   'datetime': '2012-09-19 11:56:02',
#   'seq_num_frames': 3,
#   'location': 'I02',
#   'height': 1536,
#   'seq_id': 'ASG000q1pv'},
#  {'id': 'S1/Q10/Q10_R1/S1_Q10_R1_PICT0339',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/Q10/Q10_R1/S1_Q10_R1_PICT0339.JPG',
#   'datetime': '2010-10-16 07:36:40',
#   'seq_num_frames': 3,
#   'location': 'Q10',
#   'height': 1536,
#   'seq_id': 'ASG0000f9y'},
#  {'id': 'S1/H06/H06_R4/S1_H06_R4_PICT1332',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H06/H06_R4/S1_H06_R4_PICT1332.JPG',
#   'datetime': '2010-10-26 19:56:06',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG000132a'},
#  {'id': 'S4/O09/O09_R2/S4_O09_R2_IMAG0709',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/O09/O09_R2/S4_O09_R2_IMAG0709.JPG',
#   'datetime': '2012-03-22 20:59:27',
#   'seq_num_frames': 1,
#   'location': 'O09',
#   'height': 1536,
#   'seq_id': 'ASG000drty'},
#  {'id': 'S5/N04/N04_R3/S5_N04_R3_IMAG0042',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/N04/N04_R3/S5_N04_R3_IMAG0042.JPG',
#   'datetime': '2012-10-24 08:18:24',
#   'seq_num_frames': 3,
#   'location': 'N04',
#   'height': 1536,
#   'seq_id': 'ASG000rsam'},
#  {'id': 'S3/E05/E05_R11/S3_E05_R11_IMAG0129',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E05/E05_R11/S3_E05_R11_IMAG0129.JPG',
#   'datetime': '2011-09-18 11:30:12',
#   'seq_num_frames': 3,
#   'location': 'E05',
#   'height': 1536,
#   'seq_id': 'ASG0007zrf'},
#  {'id': 'S2/G07/G07_R3/S2_G07_R3_IMAG3958',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G07/G07_R3/S2_G07_R3_IMAG3958.JPG',
#   'datetime': '2011-06-04 20:36:27',
#   'seq_num_frames': 1,
#   'location': 'G07',
#   'height': 1536,
#   'seq_id': 'ASG00058tc'},
#  {'id': 'S3/E04/E04_R12/S3_E04_R12_IMAG1483',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E04/E04_R12/S3_E04_R12_IMAG1483.JPG',
#   'datetime': '2011-12-25 08:59:42',
#   'seq_num_frames': 3,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG0009ine'},
#  {'id': 'S4/H03/H03_R1/S4_H03_R1_IMAG0043',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/H03/H03_R1/S4_H03_R1_IMAG0043.JPG',
#   'datetime': '2012-01-02 06:38:25',
#   'seq_num_frames': 1,
#   'location': 'H03',
#   'height': 1536,
#   'seq_id': 'ASG000bwb5'},
#  {'id': 'S1/H01/H01_R1/S1_H01_R1_PICT0529',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H01/H01_R1/S1_H01_R1_PICT0529.JPG',
#   'datetime': '2010-09-02 12:40:24',
#   'seq_num_frames': 3,
#   'location': 'H01',
#   'height': 1536,
#   'seq_id': 'ASG00002pt'},
#  {'id': 'S1/H11/H11_R1/S1_H11_R1_PICT5801',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H11/H11_R1/S1_H11_R1_PICT5801.JPG',
#   'datetime': '2010-10-19 04:41:46',
#   'seq_num_frames': 3,
#   'location': 'H11',
#   'height': 1536,
#   'seq_id': 'ASG00016ip'},
#  {'id': 'S5/M11/M11_R2/S5_M11_R2_IMAG0034',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/M11/M11_R2/S5_M11_R2_IMAG0034.JPG',
#   'datetime': '2012-07-27 08:42:18',
#   'seq_num_frames': 3,
#   'location': 'M11',
#   'height': 1536,
#   'seq_id': 'ASG000rk3i'},
#  {'id': 'S2/C10/C10_R3/S2_C10_R3_PICT0270',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/C10/C10_R3/S2_C10_R3_PICT0270.JPG',
#   'datetime': '2011-06-12 19:27:31',
#   'seq_num_frames': 3,
#   'location': 'C10',
#   'height': 1536,
#   'seq_id': 'ASG0003su9'},
#  {'id': 'S5/J09/J09_R2/S5_J09_R2_IMAG0932',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/J09/J09_R2/S5_J09_R2_IMAG0932.JPG',
#   'datetime': '2012-10-05 11:51:25',
#   'seq_num_frames': 3,
#   'location': 'J09',
#   'height': 1536,
#   'seq_id': 'ASG000qp5o'},
#  {'id': 'S2/F04/F04_R2/S2_F04_R2_IMAG0395',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F04/F04_R2/S2_F04_R2_IMAG0395.JPG',
#   'datetime': '2011-03-13 11:48:58',
#   'seq_num_frames': 3,
#   'location': 'F04',
#   'height': 1536,
#   'seq_id': 'ASG0004rtg'},
#  {'id': 'S2/S09/S09_R3/S2_S09_R3_IMAG1742',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/S09/S09_R3/S2_S09_R3_IMAG1742.JPG',
#   'datetime': '2011-05-31 13:39:52',
#   'seq_num_frames': 3,
#   'location': 'S09',
#   'height': 1536,
#   'seq_id': 'ASG0006pcn'},
#  {'id': 'S1/K09/K09_R1/S1_K09_R1_PICT5779',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/K09/K09_R1/S1_K09_R1_PICT5779.JPG',
#   'datetime': '2010-10-13 13:59:50',
#   'seq_num_frames': 3,
#   'location': 'K09',
#   'height': 1536,
#   'seq_id': 'ASG0001i1s'},
#  {'id': 'S3/I02/I02_R12/S3_I02_R12_IMAG0127',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/I02/I02_R12/S3_I02_R12_IMAG0127.JPG',
#   'datetime': '2011-11-08 14:33:21',
#   'seq_num_frames': 3,
#   'location': 'I02',
#   'height': 1536,
#   'seq_id': 'ASG0009urb'},
#  {'id': 'S1/N04/N04_R1/S1_N04_R1_PICT4044',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/N04/N04_R1/S1_N04_R1_PICT4044.JPG',
#   'datetime': '2010-10-21 07:49:32',
#   'seq_num_frames': 3,
#   'location': 'N04',
#   'height': 1536,
#   'seq_id': 'ASG0001ws5'},
#  {'id': 'S4/E04/E04_R2/S4_E04_R2_IMAG3039',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/E04/E04_R2/S4_E04_R2_IMAG3039.JPG',
#   'datetime': '2012-04-20 16:30:33',
#   'seq_num_frames': 3,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG000efeb'},
#  {'id': 'S6/O10/O10_R2/S6_O10_R2_IMAG0282',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/O10/O10_R2/S6_O10_R2_IMAG0282.JPG',
#   'datetime': '2013-03-07 13:06:17',
#   'seq_num_frames': 3,
#   'location': 'O10',
#   'height': 1536,
#   'seq_id': 'ASG0010wba'},
#  {'id': 'S5/O11/O11_R1/S5_O11_R1_IMAG2314',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/O11/O11_R1/S5_O11_R1_IMAG2314.JPG',
#   'datetime': '2012-05-09 09:16:20',
#   'seq_num_frames': 3,
#   'location': 'O11',
#   'height': 1536,
#   'seq_id': 'ASG000san5'},
#  {'id': 'S5/F01/F01_R3/S5_F01_R3_IMAG0070',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/F01/F01_R3/S5_F01_R3_IMAG0070.JPG',
#   'datetime': '2012-10-13 08:54:15',
#   'seq_num_frames': 3,
#   'location': 'F01',
#   'height': 1536,
#   'seq_id': 'ASG000oxso'},
#  {'id': 'S6/E09/E09_R1/S6_E09_R1_IMAG0939',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/E09/E09_R1/S6_E09_R1_IMAG0939.JPG',
#   'datetime': '2013-02-16 11:52:20',
#   'seq_num_frames': 3,
#   'location': 'E09',
#   'height': 1536,
#   'seq_id': 'ASG000yt0y'},
#  {'id': 'S2/O08/O08_R3/S2_O08_R3_IMAG0079',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/O08/O08_R3/S2_O08_R3_IMAG0079.JPG',
#   'datetime': '2011-06-06 20:15:51',
#   'seq_num_frames': 1,
#   'location': 'O08',
#   'height': 1536,
#   'seq_id': 'ASG0006a38'},
#  {'id': 'S5/N06/N06_R2/S5_N06_R2_IMAG1246',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/N06/N06_R2/S5_N06_R2_IMAG1246.JPG',
#   'datetime': '2012-10-20 11:51:59',
#   'seq_num_frames': 3,
#   'location': 'N06',
#   'height': 1536,
#   'seq_id': 'ASG000rt3h'},
#  {'id': 'S1/E03/E03_R6/S1_E03_R6_PICT0694',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/E03/E03_R6/S1_E03_R6_PICT0694.JPG',
#   'datetime': '2010-11-01 17:58:56',
#   'seq_num_frames': 3,
#   'location': 'E03',
#   'height': 1536,
#   'seq_id': 'ASG0000kvv'},
#  {'id': 'S4/Q07/Q07_R1/S4_Q07_R1_IMAG0021',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/Q07/Q07_R1/S4_Q07_R1_IMAG0021.JPG',
#   'datetime': '2012-01-20 23:54:52',
#   'seq_num_frames': 1,
#   'location': 'Q07',
#   'height': 1536,
#   'seq_id': 'ASG000etdm'},
#  {'id': 'S2/L10/L10_R2/S2_L10_R2_PICT0960',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/L10/L10_R2/S2_L10_R2_PICT0960.JPG',
#   'datetime': '2011-06-02 19:03:55',
#   'seq_num_frames': 3,
#   'location': 'L10',
#   'height': 1536,
#   'seq_id': 'ASG0007l5n'},
#  {'id': 'S5/P04/P04_R1/S5_P04_R1_IMAG0865',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/P04/P04_R1/S5_P04_R1_IMAG0865.JPG',
#   'datetime': '2012-07-16 09:15:22',
#   'seq_num_frames': 3,
#   'location': 'P04',
#   'height': 1536,
#   'seq_id': 'ASG000shmd'},
#  {'id': 'S5/K07/K07_R1/S5_K07_R1_IMAG0251',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/K07/K07_R1/S5_K07_R1_IMAG0251.JPG',
#   'datetime': '2012-06-10 13:36:33',
#   'seq_num_frames': 3,
#   'location': 'K07',
#   'height': 1536,
#   'seq_id': 'ASG000qteb'},
#  {'id': 'S5/U09/U09_R3/S5_U09_R3_IMAG0849',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/U09/U09_R3/S5_U09_R3_IMAG0849.JPG',
#   'datetime': '2012-11-07 17:41:08',
#   'seq_num_frames': 3,
#   'location': 'U09',
#   'height': 1536,
#   'seq_id': 'ASG000tr5e'},
#  {'id': 'S1/F09/F09_R1/S1_F09_R1_PICT0128',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F09/F09_R1/S1_F09_R1_PICT0128.JPG',
#   'datetime': '2010-07-29 01:46:30',
#   'seq_num_frames': 1,
#   'location': 'F09',
#   'height': 1536,
#   'seq_id': 'ASG00034vg'},
#  {'id': 'S6/T11/T11_R2/S6_T11_R2_IMAG0133',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/T11/T11_R2/S6_T11_R2_IMAG0133.JPG',
#   'datetime': '2013-03-03 15:57:36',
#   'seq_num_frames': 3,
#   'location': 'T11',
#   'height': 1536,
#   'seq_id': 'ASG0011lka'},
#  {'id': 'S2/I09/I09_R2/S2_I09_R2_PICT1280',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/I09/I09_R2/S2_I09_R2_PICT1280.JPG',
#   'datetime': '2011-04-23 05:52:10',
#   'seq_num_frames': 3,
#   'location': 'I09',
#   'height': 1536,
#   'seq_id': 'ASG0005uos'},
#  {'id': 'S5/N10/N10_R1/S5_N10_R1_IMAG0399',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/N10/N10_R1/S5_N10_R1_IMAG0399.JPG',
#   'datetime': '2012-07-21 11:48:32',
#   'seq_num_frames': 3,
#   'location': 'N10',
#   'height': 1536,
#   'seq_id': 'ASG000ru9h'},
#  {'id': 'S6/J02/J02_R2/S6_J02_R2_IMAG0396',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/J02/J02_R2/S6_J02_R2_IMAG0396.JPG',
#   'datetime': '2013-04-03 17:28:28',
#   'seq_num_frames': 3,
#   'location': 'J02',
#   'height': 1536,
#   'seq_id': 'ASG000ztai'},
#  {'id': 'S1/I07/I07_R1/S1_I07_R1_PICT2169',
#   'frame_num': 2,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/I07/I07_R1/S1_I07_R1_PICT2169.JPG',
#   'datetime': '2010-10-19 05:24:58',
#   'seq_num_frames': 3,
#   'location': 'I07',
#   'height': 1536,
#   'seq_id': 'ASG0001auj'},
#  {'id': 'S5/B12/B12_R1/S5_B12_R1_IMAG0543',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B12/B12_R1/S5_B12_R1_IMAG0543.JPG',
#   'datetime': '2012-06-21 10:38:11',
#   'seq_num_frames': 3,
#   'location': 'B12',
#   'height': 1536,
#   'seq_id': 'ASG000namg'},
#  {'id': 'S2/N11/N11_R1/S2_N11_R1_PICT0103',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/N11/N11_R1/S2_N11_R1_PICT0103.JPG',
#   'datetime': '2011-04-07 00:54:38',
#   'seq_num_frames': 3,
#   'location': 'N11',
#   'height': 1536,
#   'seq_id': 'ASG00070d8'},
#  {'id': 'S1/T13/T13_R1/S1_T13_R1_PICT2303',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/T13/T13_R1/S1_T13_R1_PICT2303.JPG',
#   'datetime': '2010-09-22 01:01:44',
#   'seq_num_frames': 3,
#   'location': 'T13',
#   'height': 1536,
#   'seq_id': 'ASG00038tl'},
#  {'id': 'S6/V10/V10_R1/S6_V10_R1_IMAG1747',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/V10/V10_R1/S6_V10_R1_IMAG1747.JPG',
#   'datetime': '2013-02-25 17:40:36',
#   'seq_num_frames': 3,
#   'location': 'V10',
#   'height': 1536,
#   'seq_id': 'ASG0011wfc'},
#  {'id': 'S3/Q05/Q05_R1/S3_Q05_R1_IMAG0011',
#   'frame_num': 1,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/Q05/Q05_R1/S3_Q05_R1_IMAG0011.JPG',
#   'datetime': '2011-09-15 13:00:28',
#   'seq_num_frames': 3,
#   'location': 'Q05',
#   'height': 1536,
#   'seq_id': 'ASG0009dty'},
#  {'id': 'S2/Q07/Q07_R1/S2_Q07_R1_IMAG0812',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/Q07/Q07_R1/S2_Q07_R1_IMAG0812.JPG',
#   'datetime': '2011-03-13 11:51:50',
#   'seq_num_frames': 3,
#   'location': 'Q07',
#   'height': 1536,
#   'seq_id': 'ASG0006h92'},
#  {'id': 'S5/L10/L10_R2/S5_L10_R2_IMAG2499',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/L10/L10_R2/S5_L10_R2_IMAG2499.JPG',
#   'datetime': '2012-09-29 23:39:10',
#   'seq_num_frames': 1,
#   'location': 'L10',
#   'height': 1536,
#   'seq_id': 'ASG000r7li'},
#  {'id': 'S2/P11/P11_R3/S2_P11_R3_PICT0203',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/P11/P11_R3/S2_P11_R3_PICT0203.JPG',
#   'datetime': '2011-05-07 13:06:21',
#   'seq_num_frames': 3,
#   'location': 'P11',
#   'height': 1536,
#   'seq_id': 'ASG0006e7f'},
#  {'id': 'S5/E04/E04_R2/S5_E04_R2_IMAG0042',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/E04/E04_R2/S5_E04_R2_IMAG0042.JPG',
#   'datetime': '2012-08-05 12:04:35',
#   'seq_num_frames': 3,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG000oixh'},
#  {'id': 'S5/I11/I11_R2/S5_I11_R2_IMAG0252',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/I11/I11_R2/S5_I11_R2_IMAG0252.JPG',
#   'datetime': '2012-08-08 15:13:39',
#   'seq_num_frames': 3,
#   'location': 'I11',
#   'height': 1536,
#   'seq_id': 'ASG000qben'},
#  {'id': 'S2/G12/G12_R3/S2_G12_R3_IMAG0396',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G12/G12_R3/S2_G12_R3_IMAG0396.JPG',
#   'datetime': '2011-07-13 14:20:15',
#   'seq_num_frames': 3,
#   'location': 'G12',
#   'height': 1536,
#   'seq_id': 'ASG0005er8'},
#  {'id': 'S2/N04/N04_R2/S2_N04_R2_PICT0039',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/N04/N04_R2/S2_N04_R2_PICT0039.JPG',
#   'datetime': '2011-03-13 15:06:16',
#   'seq_num_frames': 3,
#   'location': 'N04',
#   'height': 1536,
#   'seq_id': 'ASG0006wp3'},
#  {'id': 'S2/I09/I09_R2/S2_I09_R2_PICT0144',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/I09/I09_R2/S2_I09_R2_PICT0144.JPG',
#   'datetime': '2011-03-10 04:19:55',
#   'seq_num_frames': 3,
#   'location': 'I09',
#   'height': 1536,
#   'seq_id': 'ASG0005uae'},
#  {'id': 'S4/J10/J10_R1/S4_J10_R1_IMAG2240',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/J10/J10_R1/S4_J10_R1_IMAG2240.JPG',
#   'datetime': '2012-03-22 07:16:37',
#   'seq_num_frames': 3,
#   'location': 'J10',
#   'height': 1536,
#   'seq_id': 'ASG000c8pd'},
#  {'id': 'S5/I11/I11_R2/S5_I11_R2_IMAG0148',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/I11/I11_R2/S5_I11_R2_IMAG0148.JPG',
#   'datetime': '2012-08-08 14:31:07',
#   'seq_num_frames': 3,
#   'location': 'I11',
#   'height': 1536,
#   'seq_id': 'ASG000qbdn'},
#  {'id': 'S5/L10/L10_R2/S5_L10_R2_IMAG3211',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/L10/L10_R2/S5_L10_R2_IMAG3211.JPG',
#   'datetime': '2012-10-22 12:27:10',
#   'seq_num_frames': 3,
#   'location': 'L10',
#   'height': 1536,
#   'seq_id': 'ASG000r7ty'},
#  {'id': 'S1/I13/I13_R1/S1_I13_R1_PICT0123',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/I13/I13_R1/S1_I13_R1_PICT0123.JPG',
#   'datetime': '2010-09-14 21:24:18',
#   'seq_num_frames': 3,
#   'location': 'I13',
#   'height': 1536,
#   'seq_id': 'ASG0001cog'},
#  {'id': 'S4/U13/U13_R2/S4_U13_R2_IMAG2381',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/U13/U13_R2/S4_U13_R2_IMAG2381.JPG',
# ...
#   'seq_num_frames': 3,
#   'location': 'J13',
#   'height': 1536,
#   'seq_id': 'ASG0000unq'},
#  {'id': 'S4/L01/L01_R1/S4_L01_R1_IMAG0213',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/L01/L01_R1/S4_L01_R1_IMAG0213.JPG',
#   'datetime': '2012-03-06 13:08:35',
#   'seq_num_frames': 3,
#   'location': 'L01',
#   'height': 1536,
#   'seq_id': 'ASG000bpba'},
#  {'id': 'S3/C03/C03_R11/S3_C03_R11_IMAG0074',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/C03/C03_R11/S3_C03_R11_IMAG0074.JPG',
#   'datetime': '2011-09-08 16:12:12',
#   'seq_num_frames': 3,
#   'location': 'C03',
#   'height': 1536,
#   'seq_id': 'ASG0007xyg'},
#  {'id': 'S5/C06/C06_R3/S5_C06_R3_IMAG0009',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/C06/C06_R3/S5_C06_R3_IMAG0009.JPG',
#   'datetime': '2012-09-13 07:44:57',
#   'seq_num_frames': 3,
#   'location': 'C06',
#   'height': 1536,
#   'seq_id': 'ASG000nfqr'},
#  {'id': 'S2/G10/G10_R1/S2_G10_R1_IMAG0577',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G10/G10_R1/S2_G10_R1_IMAG0577.JPG',
#   'datetime': '2011-04-13 17:11:17',
#   'seq_num_frames': 3,
#   'location': 'G10',
#   'height': 1536,
#   'seq_id': 'ASG0005cit'},
#  {'id': 'S2/F01/F01_R1/S2_F01_R1_IMAG0099',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F01/F01_R1/S2_F01_R1_IMAG0099.JPG',
#   'datetime': '2011-03-12 15:08:24',
#   'seq_num_frames': 3,
#   'location': 'F01',
#   'height': 1536,
#   'seq_id': 'ASG0004of8'},
#  {'id': 'S6/H11/H11_R2/S6_H11_R2_IMAG0046',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/H11/H11_R2/S6_H11_R2_IMAG0046.JPG',
#   'datetime': '2013-02-13 13:09:25',
#   'seq_num_frames': 3,
#   'location': 'H11',
#   'height': 1536,
#   'seq_id': 'ASG000zmjs'},
#  {'id': 'S5/C06/C06_R1/S5_C06_R1_IMAG0129',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/C06/C06_R1/S5_C06_R1_IMAG0129.JPG',
#   'datetime': '2012-05-06 01:22:54',
#   'seq_num_frames': 1,
#   'location': 'C06',
#   'height': 1536,
#   'seq_id': 'ASG000neyn'},
#  {'id': 'S5/I03/I03_R3/S5_I03_R3_IMAG0391',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/I03/I03_R3/S5_I03_R3_IMAG0391.JPG',
#   'datetime': '2012-10-29 13:35:50',
#   'seq_num_frames': 3,
#   'location': 'I03',
#   'height': 1536,
#   'seq_id': 'ASG000q3pz'},
#  {'id': 'S4/E10/E10_R1/S4_E10_R1_IMAG0119',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/E10/E10_R1/S4_E10_R1_IMAG0119.JPG',
#   'datetime': '2012-02-26 07:15:02',
#   'seq_num_frames': 3,
#   'location': 'E10',
#   'height': 1536,
#   'seq_id': 'ASG000duf2'},
#  {'id': 'S2/F06/F06_R4/S2_F06_R4_IMAG0373',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F06/F06_R4/S2_F06_R4_IMAG0373.JPG',
#   'datetime': '2011-06-09 04:07:49',
#   'seq_num_frames': 1,
#   'location': 'F06',
#   'height': 1536,
#   'seq_id': 'ASG0004u1o'},
#  {'id': 'S5/F02/F02_R1/S5_F02_R1_IMAG0020',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/F02/F02_R1/S5_F02_R1_IMAG0020.JPG',
#   'datetime': '2012-05-17 09:37:11',
#   'seq_num_frames': 3,
#   'location': 'F02',
#   'height': 1536,
#   'seq_id': 'ASG000oxty'},
#  {'id': 'S2/G10/G10_R1/S2_G10_R1_IMAG0466',
#   'frame_num': 1,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G10/G10_R1/S2_G10_R1_IMAG0466.JPG',
#   'datetime': '2011-04-13 14:05:20',
#   'seq_num_frames': 3,
#   'location': 'G10',
#   'height': 1536,
#   'seq_id': 'ASG0005cik'},
#  {'id': 'S4/O07/O07_R2/S4_O07_R2_IMAG0035',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/O07/O07_R2/S4_O07_R2_IMAG0035.JPG',
#   'datetime': '2012-03-31 14:23:27',
#   'seq_num_frames': 3,
#   'location': 'O07',
#   'height': 1536,
#   'seq_id': 'ASG000f0zd'},
#  {'id': 'S6/J02/J02_R2/S6_J02_R2_IMAG0185',
#   'frame_num': 1,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/J02/J02_R2/S6_J02_R2_IMAG0185.JPG',
#   'datetime': '2013-02-24 16:59:59',
#   'seq_num_frames': 3,
#   'location': 'J02',
#   'height': 1536,
#   'seq_id': 'ASG000zt83'},
#  {'id': 'S2/F05/F05_R1/S2_F05_R1_IMAG0704',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F05/F05_R1/S2_F05_R1_IMAG0704.JPG',
#   'datetime': '2011-04-20 11:10:48',
#   'seq_num_frames': 3,
#   'location': 'F05',
#   'height': 1536,
#   'seq_id': 'ASG0004s8m'},
#  {'id': 'S6/S11/S11_R2/S6_S11_R2_IMAG0062',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/S11/S11_R2/S6_S11_R2_IMAG0062.JPG',
#   'datetime': '2013-02-16 10:19:46',
#   'seq_num_frames': 3,
#   'location': 'S11',
#   'height': 1536,
#   'seq_id': 'ASG0011ecr'},
#  {'id': 'S1/F09/F09_R3/S1_F09_R3_PICT1578',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F09/F09_R3/S1_F09_R3_PICT1578.JPG',
#   'datetime': '2010-10-28 05:02:04',
#   'seq_num_frames': 3,
#   'location': 'F09',
#   'height': 1536,
#   'seq_id': 'ASG0000sof'},
#  {'id': 'S1/F10/F10_R1/S1_F10_R1_PICT0438',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/F10/F10_R1/S1_F10_R1_PICT0438.JPG',
#   'datetime': '2010-10-24 13:27:28',
#   'seq_num_frames': 3,
#   'location': 'F10',
#   'height': 1536,
#   'seq_id': 'ASG0000ste'},
#  {'id': 'S2/E02/E02_R2/S2_E02_R2_PICT1028',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/E02/E02_R2/S2_E02_R2_PICT1028.JPG',
#   'datetime': '2011-03-17 11:01:08',
#   'seq_num_frames': 3,
#   'location': 'E02',
#   'height': 1536,
#   'seq_id': 'ASG0004cmu'},
#  {'id': 'S5/B13/B13_R3/S5_B13_R3_IMAG0568',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/B13/B13_R3/S5_B13_R3_IMAG0568.JPG',
#   'datetime': '2012-10-20 10:42:58',
#   'seq_num_frames': 3,
#   'location': 'B13',
#   'height': 1536,
#   'seq_id': 'ASG000mvk2'},
#  {'id': 'S6/G12/G12_R1/S6_G12_R1_IMAG0012',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/G12/G12_R1/S6_G12_R1_IMAG0012.JPG',
#   'datetime': '2012-12-11 11:32:55',
#   'seq_num_frames': 3,
#   'location': 'G12',
#   'height': 1536,
#   'seq_id': 'ASG000zaid'},
#  {'id': 'S5/F04/F04_R2/S5_F04_R2_IMAG1463',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/F04/F04_R2/S5_F04_R2_IMAG1463.JPG',
#   'datetime': '2012-07-02 07:40:13',
#   'seq_num_frames': 3,
#   'location': 'F04',
#   'height': 1536,
#   'seq_id': 'ASG000p1w1'},
#  {'id': 'S5/E04/E04_R3/S5_E04_R3_IMAG0031',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/E04/E04_R3/S5_E04_R3_IMAG0031.JPG',
#   'datetime': '2012-10-03 06:54:38',
#   'seq_num_frames': 3,
#   'location': 'E04',
#   'height': 1536,
#   'seq_id': 'ASG000oj26'},
#  {'id': 'S5/S07/S07_R2/S5_S07_R2_IMAG0229',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/S07/S07_R2/S5_S07_R2_IMAG0229.JPG',
#   'datetime': '2012-09-28 14:22:36',
#   'seq_num_frames': 3,
#   'location': 'S07',
#   'height': 1536,
#   'seq_id': 'ASG000tadp'},
#  {'id': 'S3/K07/K07_R12/S3_K07_R12_IMAG0362',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/K07/K07_R12/S3_K07_R12_IMAG0362.JPG',
#   'datetime': '2011-11-13 14:46:18',
#   'seq_num_frames': 3,
#   'location': 'K07',
#   'height': 1536,
#   'seq_id': 'ASG000acmw'},
#  {'id': 'S2/G07/G07_R1/S2_G07_R1_IMAG0067',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/G07/G07_R1/S2_G07_R1_IMAG0067.JPG',
#   'datetime': '2011-03-31 14:17:23',
#   'seq_num_frames': 3,
#   'location': 'G07',
#   'height': 1536,
#   'seq_id': 'ASG00059q2'},
#  {'id': 'S5/H08/H08_R2/S5_H08_R2_IMAG0172',
#   'frame_num': 1,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/H08/H08_R2/S5_H08_R2_IMAG0172.JPG',
#   'datetime': '2012-08-16 13:42:25',
#   'seq_num_frames': 3,
#   'location': 'H08',
#   'height': 1536,
#   'seq_id': 'ASG000pwey'},
#  {'id': 'S3/E05/E05_R12/S3_E05_R12_IMAG0204',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/E05/E05_R12/S3_E05_R12_IMAG0204.JPG',
#   'datetime': '2011-11-29 02:22:24',
#   'seq_num_frames': 1,
#   'location': 'E05',
#   'height': 1536,
#   'seq_id': 'ASG00094y8'},
#  {'id': 'S6/D13/D13_R1/S6_D13_R1_IMAG0138',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/D13/D13_R1/S6_D13_R1_IMAG0138.JPG',
#   'datetime': '2012-12-21 15:04:47',
#   'seq_num_frames': 3,
#   'location': 'D13',
#   'height': 1536,
#   'seq_id': 'ASG000yobc'},
#  {'id': 'S1/I02/I02_R1/S1_I02_R1_PICT2265',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/I02/I02_R1/S1_I02_R1_PICT2265.JPG',
#   'datetime': '2010-09-25 23:54:42',
#   'seq_num_frames': 3,
#   'location': 'I02',
#   'height': 1536,
#   'seq_id': 'ASG00017a3'},
#  {'id': 'S2/F04/F04_R2/S2_F04_R2_IMAG0162',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/F04/F04_R2/S2_F04_R2_IMAG0162.JPG',
#   'datetime': '2011-03-02 16:34:55',
#   'seq_num_frames': 3,
#   'location': 'F04',
#   'height': 1536,
#   'seq_id': 'ASG0004rxu'},
#  {'id': 'S5/V10/V10_R1/S5_V10_R1_IMAG1279',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/V10/V10_R1/S5_V10_R1_IMAG1279.JPG',
#   'datetime': '2012-05-26 11:45:01',
#   'seq_num_frames': 3,
#   'location': 'V10',
#   'height': 1536,
#   'seq_id': 'ASG000tww5'},
#  {'id': 'S2/Q09/Q09_R3/S2_Q09_R3_IMAG3543',
#   'frame_num': 0,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/Q09/Q09_R3/S2_Q09_R3_IMAG3543.JPG',
#   'datetime': '2011-07-03 12:34:55',
#   'seq_num_frames': 3,
#   'location': 'Q09',
#   'height': 1536,
#   'seq_id': 'ASG0006igb'},
#  {'id': 'S6/C01/C01_R1/S6_C01_R1_IMAG1937',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/C01/C01_R1/S6_C01_R1_IMAG1937.JPG',
#   'datetime': '2013-01-11 16:08:22',
#   'seq_num_frames': 3,
#   'location': 'C01',
#   'height': 1536,
#   'seq_id': 'ASG000y6f2'},
#  {'id': 'S1/P11/P11_R1/S1_P11_R1_PICT0041',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/P11/P11_R1/S1_P11_R1_PICT0041.JPG',
#   'datetime': '2010-10-08 00:02:34',
#   'seq_num_frames': 3,
#   'location': 'P11',
#   'height': 1536,
#   'seq_id': 'ASG0000f3g'},
#  {'id': 'S1/H06/H06_R4/S1_H06_R4_PICT1008',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H06/H06_R4/S1_H06_R4_PICT1008.JPG',
#   'datetime': '2010-09-11 06:28:40',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG00012za'},
#  {'id': 'S6/E01/E01_R1/S6_E01_R1_IMAG0138',
#   'frame_num': 2,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/E01/E01_R1/S6_E01_R1_IMAG0138.JPG',
#   'datetime': '2012-11-24 18:19:31',
#   'seq_num_frames': 3,
#   'location': 'E01',
#   'height': 1536,
#   'seq_id': 'ASG000yq1m'},
#  {'id': 'S1/T13/T13_R1/S1_T13_R1_PICT3981',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/T13/T13_R1/S1_T13_R1_PICT3981.JPG',
#   'datetime': '2010-09-28 11:39:24',
#   'seq_num_frames': 3,
#   'location': 'T13',
#   'height': 1536,
#   'seq_id': 'ASG0003994'},
#  {'id': 'S3/F07/F07_R12/S3_F07_R12_IMAG0558',
#   'frame_num': 1,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/F07/F07_R12/S3_F07_R12_IMAG0558.JPG',
#   'datetime': '2011-12-07 09:37:09',
#   'seq_num_frames': 3,
#   'location': 'F07',
#   'height': 1536,
#   'seq_id': 'ASG000993f'},
#  {'id': 'S2/M07/M07_R2/S2_M07_R2_IMAG0961',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/M07/M07_R2/S2_M07_R2_IMAG0961.JPG',
#   'datetime': '2011-06-13 16:11:24',
#   'seq_num_frames': 3,
#   'location': 'M07',
#   'height': 1536,
#   'seq_id': 'ASG0007rjg'},
#  {'id': 'S1/J08/J08_R1/S1_J08_R1_PICT0379',
#   'frame_num': 0,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/J08/J08_R1/S1_J08_R1_PICT0379.JPG',
#   'datetime': '2010-10-02 17:18:12',
#   'seq_num_frames': 3,
#   'location': 'J08',
#   'height': 1536,
#   'seq_id': 'ASG0001f0g'},
#  {'id': 'S6/I01/I01_R1/S6_I01_R1_IMAG0227',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/I01/I01_R1/S6_I01_R1_IMAG0227.JPG',
#   'datetime': '2012-12-20 11:29:39',
#   'seq_num_frames': 3,
#   'location': 'I01',
#   'height': 1536,
#   'seq_id': 'ASG000zmp5'},
#  {'id': 'S2/E01/E01_R1/S2_E01_R1_IMAG0178',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/E01/E01_R1/S2_E01_R1_IMAG0178.JPG',
#   'datetime': '2011-03-05 18:55:46',
#   'seq_num_frames': 3,
#   'location': 'E01',
#   'height': 1536,
#   'seq_id': 'ASG0004b4m'},
#  {'id': 'S6/J07/J07_R2/S6_J07_R2_IMAG0227',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/J07/J07_R2/S6_J07_R2_IMAG0227.JPG',
#   'datetime': '2012-11-25 15:21:53',
#   'seq_num_frames': 3,
#   'location': 'J07',
#   'height': 1536,
#   'seq_id': 'ASG000zuud'},
#  {'id': 'S4/C13/C13_R1/S4_C13_R1_IMAG4625',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/C13/C13_R1/S4_C13_R1_IMAG4625.JPG',
#   'datetime': '2012-02-17 13:42:41',
#   'seq_num_frames': 3,
#   'location': 'C13',
#   'height': 1536,
#   'seq_id': 'ASG000cjuq'},
#  {'id': 'S5/T10/T10_R3/S5_T10_R3_IMAG0137',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/T10/T10_R3/S5_T10_R3_IMAG0137.JPG',
#   'datetime': '2012-09-25 13:58:05',
#   'seq_num_frames': 3,
#   'location': 'T10',
#   'height': 1536,
#   'seq_id': 'ASG000tftj'},
#  {'id': 'S1/G06/G06_R3/S1_G06_R3_PICT0587',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/G06/G06_R3/S1_G06_R3_PICT0587.JPG',
#   'datetime': '2010-10-20 02:59:08',
#   'seq_num_frames': 3,
#   'location': 'G06',
#   'height': 1536,
#   'seq_id': 'ASG0000wul'},
#  {'id': 'S6/O10/O10_R1/S6_O10_R1_IMAG0094',
#   'frame_num': 0,
#   'season': 'S6',
#   'width': 2048,
#   'file_name': 'S6/O10/O10_R1/S6_O10_R1_IMAG0094.JPG',
#   'datetime': '2013-02-17 02:29:50',
#   'seq_num_frames': 1,
#   'location': 'O10',
#   'height': 1536,
#   'seq_id': 'ASG0010w7j'},
#  {'id': 'S4/H06/H06_R1/S4_H06_R1_IMAG0106',
#   'frame_num': 2,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/H06/H06_R1/S4_H06_R1_IMAG0106.JPG',
#   'datetime': '2012-03-01 09:49:54',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG000f0wp'},
#  {'id': 'S3/L11/L11_R12/S3_L11_R12_IMAG0560',
#   'frame_num': 2,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/L11/L11_R12/S3_L11_R12_IMAG0560.JPG',
#   'datetime': '2011-12-27 15:54:44',
#   'seq_num_frames': 3,
#   'location': 'L11',
#   'height': 1536,
#   'seq_id': 'ASG000akyr'},
#  {'id': 'S5/D06/D06_R1/S5_D06_R1_IMAG0010',
#   'frame_num': 0,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/D06/D06_R1/S5_D06_R1_IMAG0010.JPG',
#   'datetime': '2012-05-02 21:05:57',
#   'seq_num_frames': 1,
#   'location': 'D06',
#   'height': 1536,
#   'seq_id': 'ASG000nzh0'},
#  {'id': 'S5/N10/N10_R1/S5_N10_R1_IMAG0719',
#   'frame_num': 2,
#   'season': 'S5',
#   'width': 2048,
#   'file_name': 'S5/N10/N10_R1/S5_N10_R1_IMAG0719.JPG',
#   'datetime': '2012-08-05 14:33:56',
#   'seq_num_frames': 3,
#   'location': 'N10',
#   'height': 1536,
#   'seq_id': 'ASG000rucr'},
#  {'id': 'S3/D07/D07_R11/S3_D07_R11_IMAG0309',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/D07/D07_R11/S3_D07_R11_IMAG0309.JPG',
#   'datetime': '2011-11-03 16:49:12',
#   'seq_num_frames': 3,
#   'location': 'D07',
#   'height': 1536,
#   'seq_id': 'ASG0008z6z'},
#  {'id': 'S2/H04/H04_R3/S2_H04_R3_PICT1016',
#   'frame_num': 2,
#   'season': 'S2',
#   'width': 2048,
#   'file_name': 'S2/H04/H04_R3/S2_H04_R3_PICT1016.JPG',
#   'datetime': '2011-06-08 21:12:51',
#   'seq_num_frames': 3,
#   'location': 'H04',
#   'height': 1536,
#   'seq_id': 'ASG0005k62'},
#  {'id': 'S1/H06/H06_R3/S1_H06_R3_PICT0657',
#   'frame_num': 1,
#   'season': 'S1',
#   'width': 2048,
#   'file_name': 'S1/H06/H06_R3/S1_H06_R3_PICT0657.JPG',
#   'datetime': '2010-08-17 14:06:16',
#   'seq_num_frames': 3,
#   'location': 'H06',
#   'height': 1536,
#   'seq_id': 'ASG00007pd'},
#  {'id': 'S4/S13/S13_R2/S4_S13_R2_IMAG1653',
#   'frame_num': 0,
#   'season': 'S4',
#   'width': 2048,
#   'file_name': 'S4/S13/S13_R2/S4_S13_R2_IMAG1653.JPG',
#   'datetime': '2012-03-11 01:57:35',
#   'seq_num_frames': 1,
#   'location': 'S13',
#   'height': 1536,
#   'seq_id': 'ASG000diek'},
#  {'id': 'S3/T09/T09_R11/S3_T09_R11_IMAG0097',
#   'frame_num': 0,
#   'season': 'S3',
#   'width': 2048,
#   'file_name': 'S3/T09/T09_R11/S3_T09_R11_IMAG0097.JPG',
#   'datetime': '2011-09-29 14:41:52',
#   'seq_num_frames': 3,
#   'location': 'T09',
#   'height': 1536,
#   'seq_id': 'ASG0008tu3'},
#  ...]
